# %% [markdown]
#         Effect of Regularization Parameter Alterations on Ridge Regression Performance

# %% [markdown]
#         Trial 1: Alpha=0.0000000001

# %% [markdown]
#         Step 1: Imports and Magic Commands

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
#         Step 2: Binary Classifier

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
#         Step 3: Parametric Specification for Feature Extraction

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %% [markdown]
#         Step 4: Training and Test Datasets for Movie Reviews (we set the value of our random seed to 20)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %% [markdown]
#         Step 5: Evaluate Ridge Regression Performance for Training Set

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.0000000001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Step 6: Evaluate Ridge Regression Performance for Test Set

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2046, 'TN': 2037, 'FP': 484, 'FN': 433, 'Accuracy': 0.8166, 'Precision': 0.808695652173913, 'Recall': 0.8253327954820492, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 2: Alpha=0.000000001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.000000001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2037, 'FP': 484, 'FN': 434, 'Accuracy': 0.8164, 'Precision': 0.8086200079082642, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 3: Alpha=0.00000001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.00000001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2046, 'TN': 2037, 'FP': 484, 'FN': 433, 'Accuracy': 0.8166, 'Precision': 0.808695652173913, 'Recall': 0.8253327954820492, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 4: Alpha=0.0000001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.0000001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2046, 'TN': 2037, 'FP': 484, 'FN': 433, 'Accuracy': 0.8166, 'Precision': 0.808695652173913, 'Recall': 0.8253327954820492, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 5: Alpha=0.000001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.000001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2037, 'FP': 484, 'FN': 434, 'Accuracy': 0.8164, 'Precision': 0.8086200079082642, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 6: Alpha=0.00001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.00001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2038, 'FP': 483, 'FN': 434, 'Accuracy': 0.8166, 'Precision': 0.8089398734177216, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 7: Alpha=0.0001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.0001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2038, 'FP': 483, 'FN': 434, 'Accuracy': 0.8166, 'Precision': 0.8089398734177216, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 8: Alpha=0.001

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.001)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2037, 'FP': 484, 'FN': 434, 'Accuracy': 0.8164, 'Precision': 0.8086200079082642, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 9: Alpha=0.01

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.01)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2045, 'TN': 2039, 'FP': 482, 'FN': 434, 'Accuracy': 0.8168, 'Precision': 0.8092599920854768, 'Recall': 0.8249294070189592, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 10: Alpha=0.1

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(0.1)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2047, 'TN': 2039, 'FP': 482, 'FN': 432, 'Accuracy': 0.8172, 'Precision': 0.8094108343218663, 'Recall': 0.8257361839451391, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 11: Alpha=1

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(1)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2043, 'TN': 2041, 'FP': 480, 'FN': 436, 'Accuracy': 0.8168, 'Precision': 0.8097502972651606, 'Recall': 0.8241226300927793, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 12: Alpha=10

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(10)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2047, 'TN': 2040, 'FP': 481, 'FN': 432, 'Accuracy': 0.8174, 'Precision': 0.8097310126582279, 'Recall': 0.8257361839451391, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 13: Alpha=100

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(100)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2053, 'TN': 2047, 'FP': 474, 'FN': 426, 'Accuracy': 0.82, 'Precision': 0.8124258013454689, 'Recall': 0.8281565147236789, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 14: Alpha=1000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(1000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 9979, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2096, 'TN': 2080, 'FP': 441, 'FN': 383, 'Accuracy': 0.8352, 'Precision': 0.8261726448561293, 'Recall': 0.845502218636547, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 15: Alpha=10000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(10000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10017, 'TN': 9974, 'FP': 5, 'FN': 4, 'Accuracy': 0.99955, 'Precision': 0.9995010975853124, 'Recall': 0.9996008382396966, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2182, 'TN': 2163, 'FP': 358, 'FN': 297, 'Accuracy': 0.869, 'Precision': 0.8590551181102363, 'Recall': 0.8801936264622832, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 16: Alpha=100000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(100000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9896, 'TN': 9884, 'FP': 95, 'FN': 125, 'Accuracy': 0.989, 'Precision': 0.9904914422980683, 'Recall': 0.9875261949905199, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2226, 'TN': 2196, 'FP': 325, 'FN': 253, 'Accuracy': 0.8844, 'Precision': 0.8725989807918463, 'Recall': 0.8979427188382412, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 17: Alpha=500000

# %% [markdown]
#         We repeat for a new RDG alpha parametric value

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(500000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9600, 'TN': 9685, 'FP': 294, 'FN': 421, 'Accuracy': 0.96425, 'Precision': 0.9702850212249848, 'Recall': 0.9579882247280711, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2190, 'TN': 2153, 'FP': 368, 'FN': 289, 'Accuracy': 0.8686, 'Precision': 0.856137607505864, 'Recall': 0.8834207341670028, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 18: 1000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(1000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9496, 'TN': 9582, 'FP': 397, 'FN': 525, 'Accuracy': 0.9539, 'Precision': 0.9598706155867786, 'Recall': 0.9476100189601836, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2163, 'TN': 2133, 'FP': 388, 'FN': 316, 'Accuracy': 0.8592, 'Precision': 0.8479027832222658, 'Recall': 0.872529245663574, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 19: Alpha=10000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(10000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9536, 'TN': 9207, 'FP': 772, 'FN': 485, 'Accuracy': 0.93715, 'Precision': 0.9251067132324409, 'Recall': 0.9516016365632173, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2233, 'TN': 1986, 'FP': 535, 'FN': 246, 'Accuracy': 0.8438, 'Precision': 0.8067196531791907, 'Recall': 0.9007664380798709, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 20: Alpha=30000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(30000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9829, 'TN': 8391, 'FP': 1588, 'FN': 192, 'Accuracy': 0.911, 'Precision': 0.8609091705351668, 'Recall': 0.9808402355054385, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2358, 'TN': 1649, 'FP': 872, 'FN': 121, 'Accuracy': 0.8014, 'Precision': 0.730030959752322, 'Recall': 0.9511899959661154, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 21: Alpha=40000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(40000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9905, 'TN': 7807, 'FP': 2172, 'FN': 116, 'Accuracy': 0.8856, 'Precision': 0.8201540117578869, 'Recall': 0.9884243089512025, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2396, 'TN': 1469, 'FP': 1052, 'FN': 83, 'Accuracy': 0.773, 'Precision': 0.6948955916473318, 'Recall': 0.9665187575635337, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 22: Alpha=50000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(50000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9948, 'TN': 7098, 'FP': 2881, 'FN': 73, 'Accuracy': 0.8523, 'Precision': 0.7754306648998364, 'Recall': 0.9927152978744637, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2429, 'TN': 1267, 'FP': 1254, 'FN': 50, 'Accuracy': 0.7392, 'Precision': 0.6595166983437415, 'Recall': 0.9798305768455022, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 23: Alpha=60000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(60000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9988, 'TN': 6349, 'FP': 3630, 'FN': 33, 'Accuracy': 0.81685, 'Precision': 0.7334410339256866, 'Recall': 0.9967069154774972, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2448, 'TN': 1039, 'FP': 1482, 'FN': 31, 'Accuracy': 0.6974, 'Precision': 0.6229007633587786, 'Recall': 0.9874949576442114, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 24: Alpha=70000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(70000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 9999, 'TN': 5532, 'FP': 4447, 'FN': 22, 'Accuracy': 0.77655, 'Precision': 0.6921639208085283, 'Recall': 0.9978046103183315, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2457, 'TN': 851, 'FP': 1670, 'FN': 22, 'Accuracy': 0.6616, 'Precision': 0.5953477102011147, 'Recall': 0.991125453812021, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 25: Alpha=80000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(80000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10011, 'TN': 4681, 'FP': 5298, 'FN': 10, 'Accuracy': 0.7346, 'Precision': 0.6539290613364688, 'Recall': 0.9990020955992416, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2468, 'TN': 660, 'FP': 1861, 'FN': 11, 'Accuracy': 0.6256, 'Precision': 0.5701085701085701, 'Recall': 0.9955627269060104, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 26: Alpha=90000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(90000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10017, 'TN': 3853, 'FP': 6126, 'FN': 4, 'Accuracy': 0.6935, 'Precision': 0.6205166325961717, 'Recall': 0.9996008382396966, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2472, 'TN': 478, 'FP': 2043, 'FN': 7, 'Accuracy': 0.59, 'Precision': 0.5475083056478405, 'Recall': 0.9971762807583703, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 27: Alpha=100000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(100000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10019, 'TN': 3074, 'FP': 6905, 'FN': 2, 'Accuracy': 0.65465, 'Precision': 0.591999527298511, 'Recall': 0.9998004191198483, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2475, 'TN': 347, 'FP': 2174, 'FN': 4, 'Accuracy': 0.5644, 'Precision': 0.5323725532372553, 'Recall': 0.9983864461476402, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 28: Alpha=110000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(110000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10019, 'TN': 2375, 'FP': 7604, 'FN': 2, 'Accuracy': 0.6197, 'Precision': 0.5685184134369857, 'Recall': 0.9998004191198483, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2477, 'TN': 230, 'FP': 2291, 'FN': 2, 'Accuracy': 0.5414, 'Precision': 0.519505033557047, 'Recall': 0.9991932230738201, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 29: Alpha=117000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(117000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10020, 'TN': 1922, 'FP': 8057, 'FN': 1, 'Accuracy': 0.5971, 'Precision': 0.5542955136361122, 'Recall': 0.9999002095599242, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2478, 'TN': 171, 'FP': 2350, 'FN': 1, 'Accuracy': 0.5298, 'Precision': 0.5132560066280033, 'Recall': 0.99959661153691, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 30: Alpha=125000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(125000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 1511, 'FP': 8468, 'FN': 0, 'Accuracy': 0.5766, 'Precision': 0.5419979447238898, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2479, 'TN': 125, 'FP': 2396, 'FN': 0, 'Accuracy': 0.5208, 'Precision': 0.5085128205128205, 'Recall': 1.0, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 31: Alpha=150000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(150000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 608, 'FP': 9371, 'FN': 0, 'Accuracy': 0.53145, 'Precision': 0.5167594884488449, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2479, 'TN': 32, 'FP': 2489, 'FN': 0, 'Accuracy': 0.5022, 'Precision': 0.49899355877616747, 'Recall': 1.0, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 32: Alpha=300000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(300000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 1, 'FP': 9978, 'FN': 0, 'Accuracy': 0.5011, 'Precision': 0.5010750537526877, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2479, 'TN': 0, 'FP': 2521, 'FN': 0, 'Accuracy': 0.4958, 'Precision': 0.4958, 'Recall': 1.0, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 33: Alpha=1000000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(1000000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 0, 'FP': 9979, 'FN': 0, 'Accuracy': 0.50105, 'Precision': 0.50105, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2479, 'TN': 0, 'FP': 2521, 'FN': 0, 'Accuracy': 0.4958, 'Precision': 0.4958, 'Recall': 1.0, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
#         Trial 34: Alpha=10000000000

# %% [markdown]
#         We repeat Steps 1-6

# %%
# all imports and magic commands
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_measures import BinaryClassificationPerformance
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
help(BinaryClassificationPerformance)
# Out:
# Help on class BinaryClassificationPerformance in module my_measures:
#
# class BinaryClassificationPerformance(builtins.object)
#  |  BinaryClassificationPerformance(predictions, labels, desc, probabilities=None)
#  |
#  |  Performance measures to evaluate the fit of a binary classification model, v1.02
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, predictions, labels, desc, probabilities=None)
#  |      Initialize attributes: predictions-vector of predicted values for Y, labels-vector of labels for Y
#  |
#  |  compute_measures(self)
#  |      Compute performance measures defined by Flach p. 57
#  |
#  |  img_indices(self)
#  |      Get the indices of true and false positives to be able to locate the corresponding images in a list of image names
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# function that takes raw data and completes all preprocessing required before model fits
def process_raw_data(fn, my_random_seed, test=False):
    # read and summarize data
    movie_data = pd.read_csv(fn, sep='\t')
    print("movie_data is:", type(movie_data))
    print("movie_data has", movie_data.shape[0], "rows and", movie_data.shape[1], "columns", "\n")
    print("the data types for each of the columns in movie_data:")
    print(movie_data.dtypes, "\n")
    print("the first 10 rows in movie_data:")
    print(movie_data.head(5))
    if (not test):
        print("The rate of 'good' movie reviews in the dataset: ")
        print(movie_data['sentiment'].mean())

    # vectorize Bag of Words from review text; as sparse matrix
    if (not test): # fit_transform()
        hv = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)
        X_hv = hv.fit_transform(movie_data.review)
        fitted_transformations.append(hv)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    else: # transform() 
        X_hv = fitted_transformations[0].transform(movie_data.review)
        print("Shape of HashingVectorizer X:")
        print(X_hv.shape)
    
    # http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
    if (not test):
        transformer = TfidfTransformer()
        X_tfidf = transformer.fit_transform(X_hv)
        fitted_transformations.append(transformer)
    else:
        X_tfidf = fitted_transformations[1].transform(X_hv)
    
    # create additional quantitative features
    # features from Amazon.csv to add to feature set
    movie_data['word_count'] = movie_data['review'].str.split(' ').str.len()
    movie_data['punc_count'] = movie_data['review'].str.count("\.")

    X_quant_features = movie_data[["word_count", "punc_count"]]
    print("Look at a few rows of the new quantitative features: ")
    print(X_quant_features.head(10))
    
    # Combine all quantitative features into a single sparse matrix
    X_quant_features_csr = csr_matrix(X_quant_features)
    X_combined = hstack([X_tfidf, X_quant_features_csr])
    X_matrix = csr_matrix(X_combined) # convert to sparse matrix
    print("Size of combined bag of words and new quantitative variables matrix:")
    print(X_matrix.shape)
    
    # Create `X`, scaled matrix of features
    # feature scaling
    if (not test):
        sc = StandardScaler(with_mean=False)
        X = sc.fit_transform(X_matrix)
        fitted_transformations.append(sc)
        print(X.shape)
        y = movie_data['sentiment']
    else:
        X = fitted_transformations[2].transform(X_matrix)
        print(X.shape)
    
    # Create Training and Test Sets
    # enter an integer for the random_state parameter; any integer will work
    if (test):
        X_submission_test = X
        print("Shape of X_test for submission:")
        print(X_submission_test.shape)
        print('SUCCESS!')
        return(movie_data, X_submission_test)
    else: 
        X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = train_test_split(X, y, movie_data, test_size=0.2, random_state=my_random_seed)
        print("Shape of X_train and X_test:")
        print(X_train.shape)
        print(X_test.shape)
        print("Shape of y_train and y_test:")
        print(y_train.shape)
        print(y_test.shape)
        print("Shape of X_raw_train and X_raw_test:")
        print(X_raw_train.shape)
        print(X_raw_test.shape)
        print('SUCCESS!')
        return(X_train, X_test, y_train, y_test, X_raw_train, X_raw_test)

# %%
# create an empty list to store any use of fit_transform() to transform() later
# it is a global list to store model and feature extraction fits
fitted_transformations = []

# CHANGE FILE PATH and my_random_seed number (any integer other than 74 will do): 
X_train, X_test, y_train, y_test, X_raw_train, X_raw_test = process_raw_data(fn='/Users/jamesboyd/Desktop/moviereviews_train.tsv', my_random_seed=20)

print("Number of fits stored in `fitted_transformations` list: ")
print(len(fitted_transformations))
# Out:
# movie_data is: <class 'pandas.core.frame.DataFrame'>
# movie_data has 25000 rows and 3 columns
#
# the data types for each of the columns in movie_data:
# id           object
# sentiment     int64
# review       object
# dtype: object
#
# the first 10 rows in movie_data:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
# The rate of 'good' movie reviews in the dataset:
# 0.5
# Shape of HashingVectorizer X:
# (25000, 131072)
# Look at a few rows of the new quantitative features:
#    word_count  punc_count
# 0         433          20
# 1         158          16
# 2         378          20
# 3         379           8
# 4         367           9
# 5          89           5
# 6         112           9
# 7         132           9
# 8         163           7
# 9          43           5
# Size of combined bag of words and new quantitative variables matrix:
# (25000, 131074)
# (25000, 131074)
# Shape of X_train and X_test:
# (20000, 131074)
# (5000, 131074)
# Shape of y_train and y_test:
# (20000,)
# (5000,)
# Shape of X_raw_train and X_raw_test:
# (20000, 5)
# (5000, 5)
# SUCCESS!
# Number of fits stored in `fitted_transformations` list:
# 3

# %%
from sklearn import linear_model
rdg = linear_model.RidgeClassifier(10000000000)
rdg.fit(X_train, y_train)

rdg_performance_train = BinaryClassificationPerformance(rdg.predict(X_train), y_train, 'rdg_train')
rdg_performance_train.compute_measures()
print(rdg_performance_train.performance_measures)
# Out:
# {'Pos': 10021, 'Neg': 9979, 'TP': 10021, 'TN': 0, 'FP': 9979, 'FN': 0, 'Accuracy': 0.50105, 'Precision': 0.50105, 'Recall': 1.0, 'desc': 'rdg_train'}

# %%
fits = [rdg_performance_train]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: train set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %%
rdg_performance_test = BinaryClassificationPerformance(rdg.predict(X_test), y_test, 'rdg_test')
rdg_performance_test.compute_measures()
print(rdg_performance_test.performance_measures)
# Out:
# {'Pos': 2479, 'Neg': 2521, 'TP': 2479, 'TN': 0, 'FP': 2521, 'FN': 0, 'Accuracy': 0.4958, 'Precision': 0.4958, 'Recall': 1.0, 'desc': 'rdg_test'}

# %%
fits = [rdg_performance_test]

for fit in fits:
    plt.plot(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], 'bo')
    plt.text(fit.performance_measures['FP'] / fit.performance_measures['Neg'], 
             fit.performance_measures['TP'] / fit.performance_measures['Pos'], fit.desc)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()
